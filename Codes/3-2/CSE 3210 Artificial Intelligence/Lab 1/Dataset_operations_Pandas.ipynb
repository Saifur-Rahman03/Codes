# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('fifa21.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      ID                  Name  Age  \
# 0           0  253283     Facundo Pellistri   18
# 1           1  179813        Edinson Cavani   32
# 2           2  245541        Giovanni Reyna   17
# 3           3  233419  Raphael Dias Belloli   23
# 4           4  198710       James Rodríguez   28
#
#                                               Photo    Nationality  \
# 0  https://cdn.sofifa.com/players/253/283/20_60.png        Uruguay
# 1  https://cdn.sofifa.com/players/179/813/20_60.png        Uruguay
# 2  https://cdn.sofifa.com/players/245/541/20_60.png  United States
# 3  https://cdn.sofifa.com/players/233/419/20_60.png         Brazil
# 4  https://cdn.sofifa.com/players/198/710/20_60.png       Colombia
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/uy.png       71         87
# 1  https://cdn.sofifa.com/flags/uy.png       86         86
# 2  https://cdn.sofifa.com/flags/us.png       68         87
# ...

# %%
del data['Unnamed: 0']
pd.DataFrame(data)
# Out:
#            ID                   Name  Age  \
# 0      253283      Facundo Pellistri   18
# 1      179813         Edinson Cavani   32
# 2      245541         Giovanni Reyna   17
# 3      233419   Raphael Dias Belloli   23
# 4      198710        James Rodríguez   28
# ...       ...                    ...  ...
# 18536    5594         Rémy Vercoutre   37
# 18537    3395  Shaun Wright-Phillips   34
# 18538     388           Sol Campbell   35
# 18539    2956        Stiliyan Petrov   32
# 18540    1983     Stéphane Grichting   35
#
#                                                   Photo    Nationality  \
# 0      https://cdn.sofifa.com/players/253/283/20_60.png        Uruguay
# 1      https://cdn.sofifa.com/players/179/813/20_60.png        Uruguay
# 2      https://cdn.sofifa.com/players/245/541/20_60.png  United States
# 3      https://cdn.sofifa.com/players/233/419/20_60.png         Brazil
# 4      https://cdn.sofifa.com/players/198/710/20_60.png       Colombia
# ...

# %%
# select a column
data['Name']
# Out:
# 0            Facundo Pellistri
# 1               Edinson Cavani
# 2               Giovanni Reyna
# 3         Raphael Dias Belloli
# 4              James Rodríguez
#                  ...
# 18536           Rémy Vercoutre
# 18537    Shaun Wright-Phillips
# 18538             Sol Campbell
# 18539          Stiliyan Petrov
# 18540       Stéphane Grichting
# Name: Name, Length: 18541, dtype: object

# %%
data.Name
# Out:
# 0            Facundo Pellistri
# 1               Edinson Cavani
# 2               Giovanni Reyna
# 3         Raphael Dias Belloli
# 4              James Rodríguez
#                  ...
# 18536           Rémy Vercoutre
# 18537    Shaun Wright-Phillips
# 18538             Sol Campbell
# 18539          Stiliyan Petrov
# 18540       Stéphane Grichting
# Name: Name, Length: 18541, dtype: object

# %%
# select a row
data.iloc[1]
# Out:
# ID                                                          179813
# Name                                                Edinson Cavani
# Age                                                             32
# Photo             https://cdn.sofifa.com/players/179/813/20_60.png
# Nationality                                                Uruguay
#                                         ...
# GK Diving                                                     12.0
# GK Handling                                                    5.0
# GK Kicking                                                    13.0
# GK Positioning                                                13.0
# GK Reflexes                                                   10.0
# Name: 1, Length: 91, dtype: object

# %%
# select a row column pair
data.loc[1, 'Nationality']
# Out:
# 'Uruguay'

# %%
# selecting a slice
data[:2]
# Out:
#        ID               Name  Age  \
# 0  253283  Facundo Pellistri   18
# 1  179813     Edinson Cavani   32
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/253/283/20_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/179/813/20_60.png     Uruguay
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/uy.png       71         87
# 1  https://cdn.sofifa.com/flags/uy.png       86         86
#
#                   Club                                         Club Logo  ...  \
# 0              Peñarol  https://cdn.sofifa.com/teams/101110/light_30.png  ...
# 1  Paris Saint-Germain      https://cdn.sofifa.com/teams/73/light_30.png  ...
#
#    Penalties  Composure  Defensive Awareness Standing Tackle Sliding Tackle  \
# 0       66.0       61.0                 35.0            11.0           18.0
# 1       85.0       80.0                 57.0            48.0           39.0
#
# ...

# %%
# slicing with gap
data[::3]
# Out:
#            ID                   Name  Age  \
# 0      253283      Facundo Pellistri   18
# 3      233419   Raphael Dias Belloli   23
# 6      235619         Marcus Edwards   21
# 9      204472             Bouna Sarr   28
# 12     221479  Dominic Calvert-Lewin   23
# ...       ...                    ...  ...
# 18528     805           Jens Lehmann   39
# 18531    5459       Mamadou Bagayoko   32
# 18534    2264    Raúl Tamudo Montero   36
# 18537    3395  Shaun Wright-Phillips   34
# 18540    1983     Stéphane Grichting   35
#
#                                                   Photo  Nationality  \
# 0      https://cdn.sofifa.com/players/253/283/20_60.png      Uruguay
# 3      https://cdn.sofifa.com/players/233/419/20_60.png       Brazil
# 6      https://cdn.sofifa.com/players/235/619/20_60.png      England
# 9      https://cdn.sofifa.com/players/204/472/20_60.png       France
# 12     https://cdn.sofifa.com/players/221/479/20_60.png      England
# ...

# %%
# selecting slices by column
data.loc[:, 'Name': 'Overall']
# Out:
#                         Name  Age  \
# 0          Facundo Pellistri   18
# 1             Edinson Cavani   32
# 2             Giovanni Reyna   17
# 3       Raphael Dias Belloli   23
# 4            James Rodríguez   28
# ...                      ...  ...
# 18536         Rémy Vercoutre   37
# 18537  Shaun Wright-Phillips   34
# 18538           Sol Campbell   35
# 18539        Stiliyan Petrov   32
# 18540     Stéphane Grichting   35
#
#                                                   Photo    Nationality  \
# 0      https://cdn.sofifa.com/players/253/283/20_60.png        Uruguay
# 1      https://cdn.sofifa.com/players/179/813/20_60.png        Uruguay
# 2      https://cdn.sofifa.com/players/245/541/20_60.png  United States
# 3      https://cdn.sofifa.com/players/233/419/20_60.png         Brazil
# 4      https://cdn.sofifa.com/players/198/710/20_60.png       Colombia
# ...                                                 ...            ...
# ...

# %%
# select an item based on criteria
data.loc[data['Overall'] > 90]
# Out:
#          ID                          Name  Age  \
# 81   158023                  Lionel Messi   33
# 95    20801  C. Ronaldo dos Santos Aveiro   35
# 160  190871    Neymar da Silva Santos Jr.   28
# 205  188545            Robert Lewandowski   31
# 267  192985               Kevin De Bruyne   29
# 579  200389                     Jan Oblak   27
#
#                                                 Photo Nationality  \
# 81   https://cdn.sofifa.com/players/158/023/20_60.png   Argentina
# 95   https://cdn.sofifa.com/players/020/801/20_60.png    Portugal
# 160  https://cdn.sofifa.com/players/190/871/20_60.png      Brazil
# 205  https://cdn.sofifa.com/players/188/545/20_60.png      Poland
# 267  https://cdn.sofifa.com/players/192/985/20_60.png     Belgium
# 579  https://cdn.sofifa.com/players/200/389/20_60.png    Slovenia
#
#                                     Flag  Overall  Potential  \
# 81   https://cdn.sofifa.com/flags/ar.png       93         93
# ...

# %%
# columns names
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'Weak Foot', 'Skill Moves',
#        'International Reputation', 'Work Rate', 'Body Type', 'Real Face',
#        'Release Clause', 'Position', 'Jersey Number', 'Joined',
#        'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW',
#        'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM',
#        'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB',
#        'GK', 'Likes', 'Dislikes', 'Following', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Dribbling', 'Curve',
#        'FK Accuracy', 'Long Passing', 'Ball Control', 'Acceleration',
#        'Sprint Speed', 'Agility', 'Reactions', 'Balance', 'Shot Power',
#        'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Aggression',
# ...

# %%
data.columns[1]
# Out:
# 'Name'

# %%
# get values
data.values
# Out:
# array([[253283, 'Facundo Pellistri', 18, ..., 7.0, 8.0, 7.0],
#        [179813, 'Edinson Cavani', 32, ..., 13.0, 13.0, 10.0],
#        [245541, 'Giovanni Reyna', 17, ..., 14.0, 12.0, 7.0],
#        ...,
#        [388, 'Sol Campbell', 35, ..., 12.0, 5.0, 9.0],
#        [2956, 'Stiliyan Petrov', 32, ..., 7.0, 9.0, 15.0],
#        [1983, 'Stéphane Grichting', 35, ..., 9.0, 5.0, 5.0]], dtype=object)

# %%
data.values[0]
# Out:
# array([253283, 'Facundo Pellistri', 18,
#        'https://cdn.sofifa.com/players/253/283/20_60.png', 'Uruguay',
#        'https://cdn.sofifa.com/flags/uy.png', 71, 87, 'Peñarol',
#        'https://cdn.sofifa.com/teams/101110/light_30.png', 4900000.0,
#        500.0, 1729, 'Right', '3 ★', '3 ★', '1 ★', 'High/ Low',
#        'Lean (170-185)', 'No', 13800000.0, 'RM', 10.0, 'Jan 1, 2019',
#        '2022', "5'9", '143lbs', '65+2', '65+2', '65+2', '70+0', '68+0',
#        '68+0', '68+0', '70+0', '68+2', '68+2', '68+2', '70+2', '61+2',
#        '61+2', '61+2', '70+2', '53+2', '48+2', '48+2', '48+2', '53+2',
#        '49+2', '40+2', '40+2', '40+2', '49+2', '15+2', 91, 4, 307, 67.0,
#        60.0, 50.0, 67.0, 56.0, 74.0, 59.0, 62.0, 58.0, 70.0, 84.0, 84.0,
#        83.0, 65.0, 76.0, 68.0, 75.0, 75.0, 61.0, 61.0, 42.0, 31.0, 65.0,
#        63.0, 66.0, 61.0, 35.0, 11.0, 18.0, 9.0, 12.0, 7.0, 8.0, 7.0],
#       dtype=object)

# %%
data.values[81][1]
# Out:
# 'Lionel Messi'

# %%
data.loc[data['Name'] == 'Lionel Messi', 'Name': 'Overall']
# Out:
#             Name  Age                                             Photo  \
# 81  Lionel Messi   33  https://cdn.sofifa.com/players/158/023/20_60.png
#
#    Nationality                                 Flag  Overall
# 81   Argentina  https://cdn.sofifa.com/flags/ar.png       93
